# %% [markdown]
# # EDA Notebook
# ---

# %% [markdown]
# ## Import Modules

# %%
import pandas as pd
import pyarrow

# %% [markdown]
# ## Explore Generated Data

# %%
df_people = pd.read_parquet("D:\Documents\phantom\phantom-canon\data\parquet_store\people.parquet")

# %%
df_people
# Out:
#       person_id first_name                last_name  \
# 0             1      James  Abbott McNeill Whistler
# 1             2       Kōbō                      Abe
# 2             3   Susan L.                   Aberth
# 3             4    Nicolai               Abildgaard
# 4             5     Walter                    Abish
# ...         ...        ...                      ...
# 2299       2300      Peter                  Zumthor
# 2300       2301      Unica                     Zürn
# 2301       2302     Markus                    Zusak
# 2302       2303     Andrey              Zvyagintsev
# 2303       2304     Stefan                    Zweig
#
#                            sort_name                   display_name  \
# 0     Abbott McNeill Whistler, James  James Abbott McNeill Whistler
# 1                          Abe, Kōbō                       Kōbō Abe
# 2                   Aberth, Susan L.                Susan L. Aberth
# ...

# %%
df_works = pd.read_parquet("D:\Documents\phantom\phantom-canon\data\parquet_store\works.parquet")

# %%
df_works.head(10)
# Out:
#    work_id  work_type_id                                      primary_title  \
# 0        1             1                       Quran (Continued Centrality)
# 1        2             1                                From a Faraway Land
# 2        3             1  The Rigor of Angels: Borges, Heisenberg, Kant,...
# 3        4             1         The Vampyre and Other Tales of the Macabre
# 4        5             1                                        The Box Man
# 5        6             1                             The Woman in the Dunes
# 6        7             1                             The Woman in the Dunes
# 7        8             1                     Letters of Abelard and Heloise
# 8        9             1  Historia Calamitatum (The Story of My Misfortu...
# 9       10             1                            Sic et Non (Yes and No)
#
#   subtitle  original_language_id  creation_year_start  creation_year_end  \
# ...

# %%
df_work_contributors = pd.read_parquet("D:\Documents\phantom\phantom-canon\data\parquet_store\work_contributors.parquet")

# %%
df_work_contributors.head(10)
# Out:
#    work_id  person_id  contribution_type_id
# 0        5          2                     1
# 1        7          2                     1
# 2       11          3                     1
# 3       12          5                     1
# 4       13          5                     1
# 5       14          8                     1
# 6       16         11                     1
# 7       17         11                     1
# 8       18         11                     1
# 9       19         11                     1
